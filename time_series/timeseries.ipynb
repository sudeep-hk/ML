# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("shampoo_with_exog.csv",index_col=[0],parse_dates=True, squeeze=True)
# Out:
# C:\Users\sudee\AppData\Local\Temp\ipykernel_14364\1300016632.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   data=pd.read_csv("shampoo_with_exog.csv",index_col=[0],parse_dates=True, squeeze=True)

# %%
data.head()
# Out:
#        Sales  Inflation
# Month
# 1-Jan  266.0          1
# 2-Jan  145.9          3
# 3-Jan  183.1          5
# 4-Jan  119.3          5
# 5-Jan  180.3          4

# %%
data=data.drop('Inflation',axis=1)

# %%
data.plot()
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
data.describe()
# Out:
#             Sales
# count   36.000000
# mean   312.600000
# std    148.937164
# min    119.300000
# 25%    192.450000
# 50%    280.150000
# 75%    411.100000
# max    682.000000
